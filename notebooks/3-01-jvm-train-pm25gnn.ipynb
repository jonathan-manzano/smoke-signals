# %% [markdown]
# # Group Nine's Capstone Project

# %%
import os
from pathlib import Path


project_dp = Path('/content/drive/MyDrive/smoke-signals')
os.chdir(project_dp)
print(f"Current working directory: {Path.cwd()}")
# Out:
# Current working directory: /content/drive/MyDrive/ds-capstone

# %% [markdown]
# ## Network Repository Installaion

# %%
# !dpkg -i cuda-keyring_1.1-1_all.deb
# !apt update
# !apt install -y nvidia-open cuda-toolkit-12-8
# Out:
# (Reading database ... 126332 files and directories currently installed.)
# Preparing to unpack cuda-keyring_1.1-1_all.deb ...
# Unpacking cuda-keyring (1.1-1) over (1.1-1) ...
# Setting up cuda-keyring (1.1-1) ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,384 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,692 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,788 kB]
# Hit:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,246 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,243 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,542 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,832 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,140 kB]
# Fetched 26.1 MB in 4s (6,222 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 cuda-cccl-12-8 cuda-command-line-tools-12-8 cuda-compiler-12-8
#   cuda-crt-12-8 cuda-cudart-12-8 cuda-cudart-dev-12-8 cuda-cuobjdump-12-8
#   cuda-cupti-12-8 cuda-cupti-dev-12-8 cuda-cuxxfilt-12-8
#   cuda-documentation-12-8 cuda-driver-dev-12-8 cuda-gdb-12-8
#   cuda-libraries-12-8 cuda-libraries-dev-12-8 cuda-nsight-12-8
#   cuda-nsight-compute-12-8 cuda-nsight-systems-12-8 cuda-nvcc-12-8
#   cuda-nvdisasm-12-8 cuda-nvml-dev-12-8 cuda-nvprof-12-8 cuda-nvprune-12-8
#   cuda-nvrtc-12-8 cuda-nvrtc-dev-12-8 cuda-nvtx-12-8 cuda-nvvm-12-8
#   cuda-nvvp-12-8 cuda-opencl-12-8 cuda-opencl-dev-12-8 cuda-profiler-api-12-8
#   cuda-sanitizer-12-8 cuda-toolkit-12-8-config-common cuda-tools-12-8
#   cuda-visual-tools-12-8 dctrl-tools default-jre default-jre-headless dkms
#   fakeroot fonts-dejavu-core fonts-dejavu-extra gcc-12 gds-tools-12-8
#   keyboard-configuration libasan8 libatk-wrapper-java libatk-wrapper-java-jni
#   libcublas-12-8 libcublas-dev-12-8 libcufft-12-8 libcufft-dev-12-8
#   libcufile-12-8 libcufile-dev-12-8 libcurand-12-8 libcurand-dev-12-8
#   libcusolver-12-8 libcusolver-dev-12-8 libcusparse-12-8 libcusparse-dev-12-8
#   libfakeroot libgail-common libgail18 libgcc-12-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgudev-1.0-0 libjansson4 liblocale-gettext-perl
#   libnpp-12-8 libnpp-dev-12-8 libnvfatbin-12-8 libnvfatbin-dev-12-8
#   libnvidia-cfg1-570 libnvidia-common-570 libnvidia-compute-570
#   libnvidia-decode-570 libnvidia-encode-570 libnvidia-extra-570
#   libnvidia-fbc1-570 libnvidia-gl-570 libnvjitlink-12-8 libnvjitlink-dev-12-8
#   libnvjpeg-12-8 libnvjpeg-dev-12-8 librsvg2-common libtsan2 libudev1
#   libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcvt0 libxkbcommon-x11-0 libxtst6 libxxf86dga1 nsight-compute-2025.1.1
#   nsight-systems-2024.6.2 nvidia-compute-utils-570 nvidia-dkms-570-open
#   nvidia-driver-570-open nvidia-firmware-570-570.124.06
#   nvidia-kernel-common-570 nvidia-kernel-source-570-open nvidia-modprobe
#   nvidia-settings nvidia-utils-570 openjdk-11-jre python3-xkit
#   screen-resolution-extra switcheroo-control systemd-hwe-hwdb udev x11-utils
#   xcvt xserver-xorg-core xserver-xorg-video-nvidia-570
# Suggested packages:
#   gcc-12-locales cpp-12-doc debtags menu gcc-12-multilib gcc-12-doc gvfs
#   nvidia-driver-570 mesa-utils xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-570:i386 libnvidia-decode-570:i386
#   libnvidia-encode-570:i386 libnvidia-fbc1-570:i386 libnvidia-gl-570:i386
# The following NEW packages will be installed:
#   cpp-12 cuda-cccl-12-8 cuda-command-line-tools-12-8 cuda-compiler-12-8
#   cuda-crt-12-8 cuda-cudart-12-8 cuda-cudart-dev-12-8 cuda-cuobjdump-12-8
#   cuda-cupti-12-8 cuda-cupti-dev-12-8 cuda-cuxxfilt-12-8
#   cuda-documentation-12-8 cuda-driver-dev-12-8 cuda-gdb-12-8
#   cuda-libraries-12-8 cuda-libraries-dev-12-8 cuda-nsight-12-8
#   cuda-nsight-compute-12-8 cuda-nsight-systems-12-8 cuda-nvcc-12-8
#   cuda-nvdisasm-12-8 cuda-nvml-dev-12-8 cuda-nvprof-12-8 cuda-nvprune-12-8
#   cuda-nvrtc-12-8 cuda-nvrtc-dev-12-8 cuda-nvtx-12-8 cuda-nvvm-12-8
#   cuda-nvvp-12-8 cuda-opencl-12-8 cuda-opencl-dev-12-8 cuda-profiler-api-12-8
#   cuda-sanitizer-12-8 cuda-toolkit-12-8 cuda-toolkit-12-8-config-common
#   cuda-tools-12-8 cuda-visual-tools-12-8 dctrl-tools default-jre
#   default-jre-headless dkms fakeroot fonts-dejavu-core fonts-dejavu-extra
#   gcc-12 gds-tools-12-8 keyboard-configuration libasan8 libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-12-8 libcublas-dev-12-8 libcufft-12-8
#   libcufft-dev-12-8 libcufile-12-8 libcufile-dev-12-8 libcurand-12-8
#   libcurand-dev-12-8 libcusolver-12-8 libcusolver-dev-12-8 libcusparse-12-8
#   libcusparse-dev-12-8 libfakeroot libgail-common libgail18 libgcc-12-dev
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgudev-1.0-0 libjansson4
#   liblocale-gettext-perl libnpp-12-8 libnpp-dev-12-8 libnvfatbin-12-8
#   libnvfatbin-dev-12-8 libnvidia-cfg1-570 libnvidia-common-570
#   libnvidia-compute-570 libnvidia-decode-570 libnvidia-encode-570
#   libnvidia-extra-570 libnvidia-fbc1-570 libnvidia-gl-570 libnvjitlink-12-8
#   libnvjitlink-dev-12-8 libnvjpeg-12-8 libnvjpeg-dev-12-8 librsvg2-common
#   libtsan2 libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcvt0 libxkbcommon-x11-0 libxtst6 libxxf86dga1 nsight-compute-2025.1.1
#   nsight-systems-2024.6.2 nvidia-compute-utils-570 nvidia-dkms-570-open
#   nvidia-driver-570-open nvidia-firmware-570-570.124.06
#   nvidia-kernel-common-570 nvidia-kernel-source-570-open nvidia-modprobe
#   nvidia-open nvidia-settings nvidia-utils-570 openjdk-11-jre python3-xkit
#   screen-resolution-extra switcheroo-control systemd-hwe-hwdb udev x11-utils
#   xcvt xserver-xorg-core xserver-xorg-video-nvidia-570
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 125 newly installed, 0 to remove and 35 not upgraded.
# Need to get 3,944 MB of archives.
# After this operation, 9,426 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-12-8 12.8.90-1 [966 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-12-8 12.8.90-1 [11.4 MB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-12 amd64 12.3.0-1ubuntu1~22.04 [10.8 MB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-12-8 12.8.90-1 [4,075 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan8 amd64 12.3.0-1ubuntu1~22.04 [2,442 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan2 amd64 12.3.0-1ubuntu1~22.04 [2,477 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-12-dev amd64 12.3.0-1ubuntu1~22.04 [2,618 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12 amd64 12.3.0-1ubuntu1~22.04 [21.7 MB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 dctrl-tools amd64 2.24-3build2 [66.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dkms all 2.8.7-2ubuntu2.2 [70.1 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.15 [76.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.15 [1,557 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjansson4 amd64 2.13.1-1.1build3 [32.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.26+4-1ubuntu1~22.04 [214 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-12-8 12.8.90-1 [5,088 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcb-cursor0 amd64 0.1.1-4ubuntu1 [10.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfakeroot amd64 1.28-1ubuntu1 [31.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 fakeroot amd64 1.28-1ubuntu1 [60.4 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.14 [1,478 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xkit all 0.5.0ubuntu5 [18.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 screen-resolution-extra all 0.18.2 [4,396 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 switcheroo-control amd64 2.4-3build2 [16.5 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-12-8 12.8.90-1 [208 kB]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-12-8 12.8.90-1 [25.1 MB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-12-8 12.8.90-1 [2,398 kB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-12-8 12.8.90-1 [52.0 kB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-12-8 12.8.93-1 [10.3 MB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-12-8 12.8.1-1 [2,542 B]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-12-8 12.8.90-1 [191 kB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-8-config-common 12.8.90-1 [16.4 kB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-12-8 12.8.90-1 [170 kB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-12-8 12.8.90-1 [29.1 kB]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-12-8 12.8.90-1 [1,257 kB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvm-12-8 12.8.93-1 [43.8 MB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-crt-12-8 12.8.93-1 [81.1 kB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-12-8 12.8.93-1 [36.0 MB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-12-8 12.8.90-1 [60.6 kB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-12-8 12.8.1-1 [2,506 B]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-12-8 12.8.90-1 [49.9 kB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-12-8 12.8.93-1 [62.3 MB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-12-8 12.8.90-1 [24.0 kB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-12-8 12.8.4.1-1 [464 MB]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-12-8 11.3.3.83-1 [151 MB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-12-8 1.13.1.3-1 [886 kB]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-12-8 10.3.9.90-1 [44.8 MB]
# Get:76 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-12-8 11.7.3.90-1 [159 MB]
# Get:77 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-12-8 12.5.8.93-1 [164 MB]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-12-8 12.3.3.100-1 [131 MB]
# Get:79 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-12-8 12.8.93-1 [28.3 MB]
# Get:80 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-12-8 12.8.90-1 [743 kB]
# Get:81 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-12-8 12.3.5.92-1 [2,910 kB]
# Get:82 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-12-8 12.8.1-1 [2,610 B]
# Get:83 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-12-8 12.8.90-1 [18.6 kB]
# Get:84 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-12-8 12.8.93-1 [53.1 MB]
# Get:85 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-dev-12-8 12.8.90-1 [89.4 kB]
# Get:86 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-12-8 12.8.4.1-1 [487 MB]
# Get:87 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-12-8 11.3.3.83-1 [302 MB]
# Get:88 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-12-8 1.13.1.3-1 [2,679 kB]
# Get:89 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-12-8 10.3.9.90-1 [44.8 MB]
# Get:90 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-12-8 11.7.3.90-1 [103 MB]
# Get:91 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-12-8 12.5.8.93-1 [168 MB]
# Get:92 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-12-8 12.3.3.100-1 [130 MB]
# Get:93 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-dev-12-8 12.8.93-1 [26.1 MB]
# Get:94 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-dev-12-8 12.8.90-1 [619 kB]
# Get:95 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-12-8 12.3.5.92-1 [2,612 kB]
# Get:96 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-12-8 12.8.1-1 [2,650 B]
# Get:97 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-12-8 12.8.90-1 [119 MB]
# Get:98 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2025.1.1 2025.1.1.2-1 [295 MB]
# Get:99 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-12-8 12.8.1-1 [4,056 B]
# Get:100 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2024.6.2 2024.6.2.225-246235244400v0 [374 MB]
# Get:101 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-12-8 12.8.1-1 [3,356 B]
# Get:102 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-12-8 12.8.90-1 [127 kB]
# Get:103 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-12-8 12.8.93-1 [115 MB]
# Get:104 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-12-8 12.8.1-1 [2,946 B]
# Get:105 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-12-8 1.13.1.3-1 [39.0 MB]
# Get:106 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-12-8 12.8.1-1 [2,462 B]
# Get:107 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-8 12.8.1-1 [3,356 B]
# Get:108 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-cfg1-570 570.124.06-0ubuntu1 [145 kB]
# Get:109 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-common-570 570.124.06-0ubuntu1 [15.9 kB]
# Get:110 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-decode-570 570.124.06-0ubuntu1 [2,434 kB]
# Get:111 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-570 570.124.06-0ubuntu1 [44.1 MB]
# Get:112 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-encode-570 570.124.06-0ubuntu1 [105 kB]
# Get:113 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-extra-570 570.124.06-0ubuntu1 [72.7 kB]
# Get:114 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-fbc1-570 570.124.06-0ubuntu1 [98.2 kB]
# Get:115 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-gl-570 570.124.06-0ubuntu1 [162 MB]
# Get:116 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-compute-utils-570 570.124.06-0ubuntu1 [109 kB]
# Get:117 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-source-570-open 570.124.06-0ubuntu1 [6,481 kB]
# Get:118 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-firmware-570-570.124.06 570.124.06-0ubuntu1 [64.5 MB]
# Get:119 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-modprobe 570.124.06-0ubuntu1 [14.9 kB]
# Get:120 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-common-570 570.124.06-0ubuntu1 [98.6 kB]
# Get:121 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-dkms-570-open 570.124.06-0ubuntu1 [14.9 kB]
# Get:122 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-utils-570 570.124.06-0ubuntu1 [521 kB]
# Get:123 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  xserver-xorg-video-nvidia-570 570.124.06-0ubuntu1 [1,694 kB]
# Get:124 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-driver-570-open 570.124.06-0ubuntu1 [12.2 kB]
# Get:125 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-open 570.124.06-0ubuntu1 [2,554 B]
# Get:126 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-settings 570.124.06-0ubuntu1 [960 kB]
# Fetched 3,944 MB in 2min 8s (30.8 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 126332 files and directories currently installed.)
# Preparing to unpack .../0-liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../1-keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Selecting previously unselected package cpp-12.
# Preparing to unpack .../2-cpp-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../3-libasan8_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../4-libtsan2_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libgcc-12-dev:amd64.
# Preparing to unpack .../5-libgcc-12-dev_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package gcc-12.
# Preparing to unpack .../6-gcc-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package dctrl-tools.
# Preparing to unpack .../7-dctrl-tools_2.24-3build2_amd64.deb ...
# Unpacking dctrl-tools (2.24-3build2) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../8-dkms_2.8.7-2ubuntu2.2_all.deb ...
# Unpacking dkms (2.8.7-2ubuntu2.2) ...
# Preparing to unpack .../9-libudev1_249.11-0ubuntu3.15_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.15) over (249.11-0ubuntu3.12) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.15) ...
# Selecting previously unselected package udev.
# (Reading database ... 126692 files and directories currently installed.)
# Preparing to unpack .../000-udev_249.11-0ubuntu3.15_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.15) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../001-libjansson4_2.13.1-1.1build3_amd64.deb ...
# Unpacking libjansson4:amd64 (2.13.1-1.1build3) ...
# Selecting previously unselected package cuda-cccl-12-8.
# Preparing to unpack .../002-cuda-cccl-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cccl-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-cupti-12-8.
# Preparing to unpack .../003-cuda-cupti-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cupti-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-cupti-dev-12-8.
# Preparing to unpack .../004-cuda-cupti-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cupti-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvdisasm-12-8.
# Preparing to unpack .../005-cuda-nvdisasm-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nvdisasm-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-8.
# Preparing to unpack .../006-cuda-cuobjdump-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-gdb-12-8.
# Preparing to unpack .../007-cuda-gdb-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-gdb-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvprof-12-8.
# Preparing to unpack .../008-cuda-nvprof-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nvprof-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvtx-12-8.
# Preparing to unpack .../009-cuda-nvtx-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nvtx-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-sanitizer-12-8.
# Preparing to unpack .../010-cuda-sanitizer-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-sanitizer-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-command-line-tools-12-8.
# Preparing to unpack .../011-cuda-command-line-tools-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-command-line-tools-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-8.
# Preparing to unpack .../012-cuda-cuxxfilt-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-toolkit-12-8-config-common.
# Preparing to unpack .../013-cuda-toolkit-12-8-config-common_12.8.90-1_all.deb ...
# Unpacking cuda-toolkit-12-8-config-common (12.8.90-1) ...
# Selecting previously unselected package cuda-cudart-12-8.
# Preparing to unpack .../014-cuda-cudart-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cudart-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-driver-dev-12-8.
# Preparing to unpack .../015-cuda-driver-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-8.
# Preparing to unpack .../016-cuda-cudart-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvvm-12-8.
# Preparing to unpack .../017-cuda-nvvm-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvvm-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-crt-12-8.
# Preparing to unpack .../018-cuda-crt-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-crt-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-nvcc-12-8.
# Preparing to unpack .../019-cuda-nvcc-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvcc-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-nvprune-12-8.
# Preparing to unpack .../020-cuda-nvprune-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nvprune-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-compiler-12-8.
# Preparing to unpack .../021-cuda-compiler-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-compiler-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-documentation-12-8.
# Preparing to unpack .../022-cuda-documentation-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-documentation-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvrtc-12-8.
# Preparing to unpack .../023-cuda-nvrtc-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-opencl-12-8.
# Preparing to unpack .../024-cuda-opencl-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-opencl-12-8 (12.8.90-1) ...
# Selecting previously unselected package libcublas-12-8.
# Preparing to unpack .../025-libcublas-12-8_12.8.4.1-1_amd64.deb ...
# Unpacking libcublas-12-8 (12.8.4.1-1) ...
# Selecting previously unselected package libcufft-12-8.
# Preparing to unpack .../026-libcufft-12-8_11.3.3.83-1_amd64.deb ...
# Unpacking libcufft-12-8 (11.3.3.83-1) ...
# Selecting previously unselected package libcufile-12-8.
# Preparing to unpack .../027-libcufile-12-8_1.13.1.3-1_amd64.deb ...
# Unpacking libcufile-12-8 (1.13.1.3-1) ...
# Selecting previously unselected package libcurand-12-8.
# Preparing to unpack .../028-libcurand-12-8_10.3.9.90-1_amd64.deb ...
# Unpacking libcurand-12-8 (10.3.9.90-1) ...
# Selecting previously unselected package libcusolver-12-8.
# Preparing to unpack .../029-libcusolver-12-8_11.7.3.90-1_amd64.deb ...
# Unpacking libcusolver-12-8 (11.7.3.90-1) ...
# Selecting previously unselected package libcusparse-12-8.
# Preparing to unpack .../030-libcusparse-12-8_12.5.8.93-1_amd64.deb ...
# Unpacking libcusparse-12-8 (12.5.8.93-1) ...
# Selecting previously unselected package libnpp-12-8.
# Preparing to unpack .../031-libnpp-12-8_12.3.3.100-1_amd64.deb ...
# Unpacking libnpp-12-8 (12.3.3.100-1) ...
# Selecting previously unselected package libnvjitlink-12-8.
# Preparing to unpack .../032-libnvjitlink-12-8_12.8.93-1_amd64.deb ...
# Unpacking libnvjitlink-12-8 (12.8.93-1) ...
# Selecting previously unselected package libnvfatbin-12-8.
# Preparing to unpack .../033-libnvfatbin-12-8_12.8.90-1_amd64.deb ...
# Unpacking libnvfatbin-12-8 (12.8.90-1) ...
# Selecting previously unselected package libnvjpeg-12-8.
# Preparing to unpack .../034-libnvjpeg-12-8_12.3.5.92-1_amd64.deb ...
# Unpacking libnvjpeg-12-8 (12.3.5.92-1) ...
# Selecting previously unselected package cuda-libraries-12-8.
# Preparing to unpack .../035-cuda-libraries-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-libraries-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-profiler-api-12-8.
# Preparing to unpack .../036-cuda-profiler-api-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-profiler-api-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-12-8.
# Preparing to unpack .../037-cuda-nvrtc-dev-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-opencl-dev-12-8.
# Preparing to unpack .../038-cuda-opencl-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-opencl-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package libcublas-dev-12-8.
# Preparing to unpack .../039-libcublas-dev-12-8_12.8.4.1-1_amd64.deb ...
# Unpacking libcublas-dev-12-8 (12.8.4.1-1) ...
# Selecting previously unselected package libcufft-dev-12-8.
# Preparing to unpack .../040-libcufft-dev-12-8_11.3.3.83-1_amd64.deb ...
# Unpacking libcufft-dev-12-8 (11.3.3.83-1) ...
# Selecting previously unselected package libcufile-dev-12-8.
# Preparing to unpack .../041-libcufile-dev-12-8_1.13.1.3-1_amd64.deb ...
# Unpacking libcufile-dev-12-8 (1.13.1.3-1) ...
# Selecting previously unselected package libcurand-dev-12-8.
# Preparing to unpack .../042-libcurand-dev-12-8_10.3.9.90-1_amd64.deb ...
# Unpacking libcurand-dev-12-8 (10.3.9.90-1) ...
# Selecting previously unselected package libcusolver-dev-12-8.
# Preparing to unpack .../043-libcusolver-dev-12-8_11.7.3.90-1_amd64.deb ...
# Unpacking libcusolver-dev-12-8 (11.7.3.90-1) ...
# Selecting previously unselected package libcusparse-dev-12-8.
# Preparing to unpack .../044-libcusparse-dev-12-8_12.5.8.93-1_amd64.deb ...
# Unpacking libcusparse-dev-12-8 (12.5.8.93-1) ...
# Selecting previously unselected package libnpp-dev-12-8.
# Preparing to unpack .../045-libnpp-dev-12-8_12.3.3.100-1_amd64.deb ...
# Unpacking libnpp-dev-12-8 (12.3.3.100-1) ...
# Selecting previously unselected package libnvjitlink-dev-12-8.
# Preparing to unpack .../046-libnvjitlink-dev-12-8_12.8.93-1_amd64.deb ...
# Unpacking libnvjitlink-dev-12-8 (12.8.93-1) ...
# Selecting previously unselected package libnvfatbin-dev-12-8.
# Preparing to unpack .../047-libnvfatbin-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking libnvfatbin-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package libnvjpeg-dev-12-8.
# Preparing to unpack .../048-libnvjpeg-dev-12-8_12.3.5.92-1_amd64.deb ...
# Unpacking libnvjpeg-dev-12-8 (12.3.5.92-1) ...
# Selecting previously unselected package cuda-libraries-dev-12-8.
# Preparing to unpack .../049-cuda-libraries-dev-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-libraries-dev-12-8 (12.8.1-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../050-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../051-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../052-openjdk-11-jre_11.0.26+4-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.26+4-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../053-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-12-8.
# Preparing to unpack .../054-cuda-nsight-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nsight-12-8 (12.8.90-1) ...
# Selecting previously unselected package nsight-compute-2025.1.1.
# Preparing to unpack .../055-nsight-compute-2025.1.1_2025.1.1.2-1_amd64.deb ...
# Unpacking nsight-compute-2025.1.1 (2025.1.1.2-1) ...
# Selecting previously unselected package cuda-nsight-compute-12-8.
# Preparing to unpack .../056-cuda-nsight-compute-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-nsight-compute-12-8 (12.8.1-1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../057-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../058-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../059-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../060-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../061-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../062-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../063-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../064-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../065-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-cursor0:amd64.
# Preparing to unpack .../066-libxcb-cursor0_0.1.1-4ubuntu1_amd64.deb ...
# Unpacking libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Selecting previously unselected package nsight-systems-2024.6.2.
# Preparing to unpack .../067-nsight-systems-2024.6.2_2024.6.2.225-246235244400v0_amd64.deb ...
# Unpacking nsight-systems-2024.6.2 (2024.6.2.225-246235244400v0) ...
# Selecting previously unselected package cuda-nsight-systems-12-8.
# Preparing to unpack .../068-cuda-nsight-systems-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-nsight-systems-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-nvml-dev-12-8.
# Preparing to unpack .../069-cuda-nvml-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nvml-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvvp-12-8.
# Preparing to unpack .../070-cuda-nvvp-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvvp-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-visual-tools-12-8.
# Preparing to unpack .../071-cuda-visual-tools-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-visual-tools-12-8 (12.8.1-1) ...
# Selecting previously unselected package gds-tools-12-8.
# Preparing to unpack .../072-gds-tools-12-8_1.13.1.3-1_amd64.deb ...
# Unpacking gds-tools-12-8 (1.13.1.3-1) ...
# Selecting previously unselected package cuda-tools-12-8.
# Preparing to unpack .../073-cuda-tools-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-tools-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-toolkit-12-8.
# Preparing to unpack .../074-cuda-toolkit-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-toolkit-12-8 (12.8.1-1) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../075-libfakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.28-1ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../076-fakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.28-1ubuntu1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../077-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../078-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../079-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../080-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../081-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../082-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../083-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../084-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../085-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../086-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../087-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../088-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libnvidia-cfg1-570:amd64.
# Preparing to unpack .../089-libnvidia-cfg1-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-common-570.
# Preparing to unpack .../090-libnvidia-common-570_570.124.06-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-decode-570:amd64.
# Preparing to unpack .../091-libnvidia-decode-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-570:amd64.
# Preparing to unpack .../092-libnvidia-compute-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-570:amd64.
# Preparing to unpack .../093-libnvidia-encode-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-570:amd64.
# Preparing to unpack .../094-libnvidia-extra-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-570:amd64.
# Preparing to unpack .../095-libnvidia-fbc1-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-570:amd64.
# Preparing to unpack .../096-libnvidia-gl-570_570.124.06-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-535
# Unpacking libnvidia-gl-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../097-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../098-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package nvidia-compute-utils-570.
# Preparing to unpack .../099-nvidia-compute-utils-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-570-open.
# Preparing to unpack .../100-nvidia-kernel-source-570-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-570-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-firmware-570-570.124.06.
# Preparing to unpack .../101-nvidia-firmware-570-570.124.06_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-firmware-570-570.124.06 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../102-nvidia-modprobe_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-570.
# Preparing to unpack .../103-nvidia-kernel-common-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-570-open.
# Preparing to unpack .../104-nvidia-dkms-570-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-570-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-570.
# Preparing to unpack .../105-nvidia-utils-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../106-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.14_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-570.
# Preparing to unpack .../107-xserver-xorg-video-nvidia-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-570-open.
# Preparing to unpack .../108-nvidia-driver-570-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-570-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-open.
# Preparing to unpack .../109-nvidia-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../110-python3-xkit_0.5.0ubuntu5_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu5) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../111-screen-resolution-extra_0.18.2_all.deb ...
# Unpacking screen-resolution-extra (0.18.2) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../112-nvidia-settings_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (570.124.06-0ubuntu1) ...
# Selecting previously unselected package switcheroo-control.
# Preparing to unpack .../113-switcheroo-control_2.4-3build2_amd64.deb ...
# Unpacking switcheroo-control (2.4-3build2) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../114-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../115-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Setting up nvidia-firmware-570-570.124.06 (570.124.06-0ubuntu1) ...
# Setting up cuda-nvprof-12-8 (12.8.90-1) ...
# Setting up nvidia-kernel-source-570-open (570.124.06-0ubuntu1) ...
# Setting up cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cuobjdump-12-8 (12.8.90-1) ...
# Setting up cuda-nvrtc-12-8 (12.8.93-1) ...
# Setting up libnvidia-extra-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up cuda-sanitizer-12-8 (12.8.93-1) ...
# Setting up cuda-nvvm-12-8 (12.8.93-1) ...
# Setting up cuda-nvprune-12-8 (12.8.90-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-cupti-12-8 (12.8.90-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up cuda-nvml-dev-12-8 (12.8.90-1) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.26+4-1ubuntu1~22.04) ...
# Setting up cuda-toolkit-12-8-config-common (12.8.90-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.8 to provide /usr/local/cuda (cuda) in auto mode
# update-alternatives: using /usr/local/cuda-12.8 to provide /usr/local/cuda-12 (cuda-12) in auto mode
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-nvrtc-dev-12-8 (12.8.93-1) ...
# Setting up libfakeroot:amd64 (1.28-1ubuntu1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libjansson4:amd64 (2.13.1-1.1build3) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up nvidia-modprobe (570.124.06-0ubuntu1) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up fakeroot (1.28-1ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up cuda-driver-dev-12-8 (12.8.90-1) ...
# Setting up libnvidia-common-570 (570.124.06-0ubuntu1) ...
# Setting up cuda-documentation-12-8 (12.8.90-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvvp-12-8 (12.8.93-1) ...
# Setting up libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Setting up cuda-profiler-api-12-8 (12.8.90-1) ...
# Setting up libnvidia-cfg1-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libcusolver-12-8 (11.7.3.90-1) ...
# Setting up udev (249.11-0ubuntu3.15) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up cuda-nvdisasm-12-8 (12.8.90-1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libnvfatbin-12-8 (12.8.90-1) ...
# Setting up libnvjpeg-12-8 (12.3.5.92-1) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libcusolver-dev-12-8 (11.7.3.90-1) ...
# Setting up libcufile-12-8 (1.13.1.3-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.8/gds/cufile.json to provide /etc/cufile.json (cufile.json) in auto mode
# Setting up libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up cuda-cuxxfilt-12-8 (12.8.90-1) ...
# Setting up cuda-nvtx-12-8 (12.8.90-1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libnvfatbin-dev-12-8 (12.8.90-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-cccl-12-8 (12.8.90-1) ...
# Setting up python3-xkit (0.5.0ubuntu5) ...
# Setting up cuda-cudart-12-8 (12.8.90-1) ...
# Setting up cuda-cupti-dev-12-8 (12.8.90-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up libnvidia-fbc1-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up dctrl-tools (2.24-3build2) ...
# Setting up cuda-nsight-12-8 (12.8.90-1) ...
# Setting up cuda-cudart-dev-12-8 (12.8.90-1) ...
# Setting up gds-tools-12-8 (1.13.1.3-1) ...
# Setting up nsight-compute-2025.1.1 (2025.1.1.2-1) ...
# Setting up nvidia-kernel-common-570 (570.124.06-0ubuntu1) ...
# Setting up cuda-crt-12-8 (12.8.93-1) ...
# Setting up libcufft-12-8 (11.3.3.83-1) ...
# Setting up libcublas-12-8 (12.8.4.1-1) ...
# Setting up libcusparse-12-8 (12.5.8.93-1) ...
# Setting up libnvjpeg-dev-12-8 (12.3.5.92-1) ...
# Setting up libnvidia-gl-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libnvjitlink-12-8 (12.8.93-1) ...
# Setting up libcufile-dev-12-8 (1.13.1.3-1) ...
# Setting up libcurand-12-8 (10.3.9.90-1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libcufft-dev-12-8 (11.3.3.83-1) ...
# Setting up libnpp-12-8 (12.3.3.100-1) ...
# Setting up libnpp-dev-12-8 (12.3.3.100-1) ...
# Setting up cuda-opencl-12-8 (12.8.90-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up cuda-gdb-12-8 (12.8.90-1) ...
# Setting up nsight-systems-2024.6.2 (2024.6.2.225-246235244400v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2024.6.2/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2024.6.2/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libnvjitlink-dev-12-8 (12.8.93-1) ...
# Setting up libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-libraries-12-8 (12.8.1-1) ...
# Setting up cuda-nsight-systems-12-8 (12.8.1-1) ...
# Setting up screen-resolution-extra (0.18.2) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libcurand-dev-12-8 (10.3.9.90-1) ...
# Setting up cuda-nsight-compute-12-8 (12.8.1-1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up switcheroo-control (2.4-3build2) ...
# Created symlink /etc/systemd/system/graphical.target.wants/switcheroo-control.service → /lib/systemd/system/switcheroo-control.service.
# Setting up nvidia-settings (570.124.06-0ubuntu1) ...
# Setting up libcusparse-dev-12-8 (12.5.8.93-1) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libcublas-dev-12-8 (12.8.4.1-1) ...
# Setting up cuda-nvcc-12-8 (12.8.93-1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up cuda-opencl-dev-12-8 (12.8.90-1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Setting up cuda-command-line-tools-12-8 (12.8.1-1) ...
# Setting up gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-compiler-12-8 (12.8.1-1) ...
# Setting up cuda-libraries-dev-12-8 (12.8.1-1) ...
# Setting up cuda-visual-tools-12-8 (12.8.1-1) ...
# Setting up cuda-tools-12-8 (12.8.1-1) ...
# Setting up cuda-toolkit-12-8 (12.8.1-1) ...
# Setting up xserver-xorg-video-nvidia-570 (570.124.06-0ubuntu1) ...
# Setting up dkms (2.8.7-2ubuntu2.2) ...
# Setting up nvidia-dkms-570-open (570.124.06-0ubuntu1) ...
# Loading new nvidia-570.124.06 DKMS files...
# It is likely that 6.1.123+ belongs to a chroot's host
# Building for 5.15.0-136-generic
# Building for architecture x86_64
# Building initial module for 5.15.0-136-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-136-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-136-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-136-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-136-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-136-generic/updates/dkms/
#
# depmod...
# Setting up libnvidia-decode-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libnvidia-compute-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libnvidia-encode-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up nvidia-utils-570 (570.124.06-0ubuntu1) ...
# Setting up nvidia-compute-utils-570 (570.124.06-0ubuntu1) ...
# Setting up nvidia-driver-570-open (570.124.06-0ubuntu1) ...
# Setting up nvidia-open (570.124.06-0ubuntu1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
# Fri Apr 18 02:01:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             48W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Install Dependencies

# %% [markdown]
# ### PyTorch

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 102.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# ### Other Dependencies

# %%
# !pip install arrow bresenham torch_geometric metpy
# Out:
# Collecting arrow
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting bresenham
#   Downloading bresenham-0.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.4 MB/s eta 0:00:00
# Collecting metpy
#   Downloading MetPy-1.6.3-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from arrow) (2.8.2)
# Collecting types-python-dateutil>=2.8.10 (from arrow)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from metpy) (3.10.0)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from metpy) (2.2.2)
# Collecting pint>=0.17 (from metpy)
#   Downloading Pint-0.24.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pooch>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from metpy) (1.8.2)
# Requirement already satisfied: pyproj>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from metpy) (3.7.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from metpy) (1.14.1)
# Requirement already satisfied: traitlets>=5.0.5 in /usr/local/lib/python3.11/dist-packages (from metpy) (5.7.1)
# Requirement already satisfied: xarray>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from metpy) (2025.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->metpy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->metpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->metpy) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->metpy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->metpy) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->metpy) (11.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->metpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->metpy) (2025.2)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pint>=0.17->metpy) (4.3.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from pint>=0.17->metpy) (4.13.1)
# Collecting flexcache>=0.3 (from pint>=0.17->metpy)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint>=0.17->metpy)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyproj>=3.0.0->metpy) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7.0->arrow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.9 MB/s eta 0:00:00
# Downloading bresenham-0.2.1-py3-none-any.whl (3.7 kB)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.6 MB/s eta 0:00:00
# Downloading MetPy-1.6.3-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.9/409.9 kB 32.1 MB/s eta 0:00:00
# Downloading Pint-0.24.4-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.5 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Installing collected packages: bresenham, types-python-dateutil, flexparser, flexcache, pint, arrow, torch_geometric, metpy
# Successfully installed arrow-1.3.0 bresenham-0.2.1 flexcache-0.3 flexparser-0.4 metpy-1.6.3 pint-0.24.4 torch_geometric-2.6.1 types-python-dateutil-2.9.0.20241206

# %%
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.6.0+cu124.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.6.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.6.0%2Bcu124/pyg_lib-0.4.0%2Bpt26cu124-cp311-cp311-linux_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 71.0 MB/s eta 0:00:00
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.6.0%2Bcu124/torch_scatter-2.1.2%2Bpt26cu124-cp311-cp311-linux_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 136.0 MB/s eta 0:00:00
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.6.0%2Bcu124/torch_sparse-0.6.18%2Bpt26cu124-cp311-cp311-linux_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 122.5 MB/s eta 0:00:00
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.6.0%2Bcu124/torch_cluster-1.6.3%2Bpt26cu124-cp311-cp311-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 114.3 MB/s eta 0:00:00
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.6.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt26cu124-cp311-cp311-linux_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from torch_sparse) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy->torch_sparse) (2.0.2)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt26cu124 torch_cluster-1.6.3+pt26cu124 torch_scatter-2.1.2+pt26cu124 torch_sparse-0.6.18+pt26cu124 torch_spline_conv-1.2.2+pt26cu124

# %%
import pm25_forecasting_gnn


# %run -m pm25_forecasting_gnn.train
# Out:
# cuda
# ============== Train Info ==============
# Dataset number: 1
# Model: PM25_GNN
# Train: 2017-01-02T00:00:00+00:00 --> 2018-12-31T00:00:00+00:00
# Val: 2020-01-01T00:00:00+00:00 --> 2020-12-31T00:00:00+00:00
# Test: 2021-01-01T00:00:00+00:00 --> 2021-12-31T00:00:00+00:00
# City number: 112
# Use metero: ['100m_u_component_of_wind', '100m_v_component_of_wind', '2m_dewpoint_temperature', '2m_temperature', 'boundary_layer_height', 'total_precipitation', 'surface_pressure', 'u_component_of_wind+950', 'v_component_of_wind+950', 'frp_25km_idw', 'frp_50km_idw', 'frp_100km_idw', 'frp_500km_idw', 'numfires', 'julian_date', 'time_of_day']
# batch_size: 16
# epochs: 50
# hist_len: 240
# pred_len: 48
# weight_decay: 0.0005
# early_stop: 10
# lr: 0.0005
# ========================================
#
#
# No. 0 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [05:00,  3.57it/s]
# 529it [01:31,  5.78it/s]
# train_loss: 0.5960
# val_loss: 0.7016
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/00/model.pth
# Train loss: 0.5960, Val loss: 0.7016, Test loss: 0.7325, RMSE: 2.72, MAE: 0.90, CSI: 0.8177, POD: 0.8646, FAR: 0.0622
#
# Train epoch 1:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 0.5017
# val_loss: 0.7455
#
# Train epoch 2:
# 1074it [04:29,  3.99it/s]
# 529it [01:19,  6.66it/s]
# train_loss: 0.7692
# val_loss: 1.5145
#
# Train epoch 3:
# 1074it [04:41,  3.82it/s]
# 529it [01:21,  6.46it/s]
# train_loss: 8.2940
# val_loss: 19.8332
#
# Train epoch 4:
# 1074it [04:39,  3.84it/s]
# 529it [01:20,  6.54it/s]
# train_loss: 32.3072
# val_loss: 39.3281
#
# Train epoch 5:
# 1074it [04:43,  3.79it/s]
# 529it [01:22,  6.44it/s]
# train_loss: 229.5899
# val_loss: 433.8422
#
# Train epoch 6:
# 1074it [04:33,  3.93it/s]
# 529it [01:20,  6.54it/s]
# train_loss: 531.7044
# val_loss: 677.3245
#
# Train epoch 7:
# 1074it [04:34,  3.92it/s]
# 529it [01:20,  6.59it/s]
# train_loss: 1151.7618
# val_loss: 1687.3012
#
# Train epoch 8:
# 1074it [04:34,  3.91it/s]
# 529it [01:20,  6.61it/s]
# train_loss: 2097.8010
# val_loss: 2467.0491
#
# Train epoch 9:
# 1074it [04:34,  3.92it/s]
# 529it [01:20,  6.57it/s]
# train_loss: 3111.0845
# val_loss: 3720.0861
#
# Train epoch 10:
# 1074it [04:34,  3.91it/s]
# 529it [01:20,  6.61it/s]
# train_loss: 4222.4509
# val_loss: 4943.3931
#
# Train epoch 11:
# 1074it [04:39,  3.84it/s]
# 529it [01:21,  6.50it/s]
# train_loss: 5892.5346
# val_loss: 6905.8388
#
# No. 0 experiment results:
# Train loss: 0.5960, Val loss: 0.7016, Test loss: 0.7325, RMSE: 2.72, MAE: 0.90, CSI: 0.8177, POD: 0.8646, FAR: 0.0622
#
# No. 1 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:37,  3.87it/s]
# 529it [01:19,  6.63it/s]
# train_loss: 0.5967
# val_loss: 0.7190
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/01/model.pth
# Train loss: 0.5967, Val loss: 0.7190, Test loss: 0.7388, RMSE: 2.74, MAE: 0.90, CSI: 0.8219, POD: 0.8533, FAR: 0.0430
#
# Train epoch 1:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.5441
# val_loss: 0.6787
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/01/model.pth
# Train loss: 0.5441, Val loss: 0.6787, Test loss: 0.7317, RMSE: 2.76, MAE: 0.92, CSI: 0.8186, POD: 0.8599, FAR: 0.0554
#
# Train epoch 2:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 0.5571
# val_loss: 0.7242
#
# Train epoch 3:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 0.6194
# val_loss: 1.7310
#
# Train epoch 4:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 3.9393
# val_loss: 4.3687
#
# Train epoch 5:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.88it/s]
# train_loss: 37.7541
# val_loss: 79.2182
#
# Train epoch 6:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.88it/s]
# train_loss: 125.5421
# val_loss: 178.7467
#
# Train epoch 7:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 356.4508
# val_loss: 648.8620
#
# Train epoch 8:
# 1074it [04:29,  3.99it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 885.2216
# val_loss: 990.2393
#
# Train epoch 9:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 961.0255
# val_loss: 1019.8655
#
# Train epoch 10:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 1032.5939
# val_loss: 1037.9917
#
# Train epoch 11:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 1121.2955
# val_loss: 1298.1814
#
# Train epoch 12:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 1611.3915
# val_loss: 2440.4735
#
# No. 1 experiment results:
# Train loss: 0.5441, Val loss: 0.6787, Test loss: 0.7317, RMSE: 2.76, MAE: 0.92, CSI: 0.8186, POD: 0.8599, FAR: 0.0554
#
# No. 2 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 0.5971
# val_loss: 0.6604
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/02/model.pth
# Train loss: 0.5971, Val loss: 0.6604, Test loss: 0.7317, RMSE: 2.74, MAE: 0.91, CSI: 0.8229, POD: 0.8544, FAR: 0.0428
#
# Train epoch 1:
# 1074it [04:34,  3.92it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 0.5467
# val_loss: 0.7405
#
# Train epoch 2:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.96it/s]
# train_loss: 0.5575
# val_loss: 0.7267
#
# Train epoch 3:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.6818
# val_loss: 1.4467
#
# Train epoch 4:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 135.2655
# val_loss: 354.3964
#
# Train epoch 5:
# 1074it [04:29,  3.99it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 586.9483
# val_loss: 849.2579
#
# Train epoch 6:
# 1074it [04:30,  3.96it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 1115.9312
# val_loss: 1351.4383
#
# Train epoch 7:
# 1074it [04:30,  3.96it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 1377.2025
# val_loss: 1231.4236
#
# Train epoch 8:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 1130.1659
# val_loss: 1060.1765
#
# Train epoch 9:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 1193.1946
# val_loss: 1382.4192
#
# Train epoch 10:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 1458.5531
# val_loss: 1546.6352
#
# Train epoch 11:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 1659.6168
# val_loss: 1761.0033
#
# No. 2 experiment results:
# Train loss: 0.5971, Val loss: 0.6604, Test loss: 0.7317, RMSE: 2.74, MAE: 0.91, CSI: 0.8229, POD: 0.8544, FAR: 0.0428
#
# No. 3 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:30,  3.98it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 0.6012
# val_loss: 0.6915
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/03/model.pth
# Train loss: 0.6012, Val loss: 0.6915, Test loss: 0.7444, RMSE: 2.73, MAE: 0.89, CSI: 0.8242, POD: 0.8576, FAR: 0.0451
#
# Train epoch 1:
# 1074it [04:44,  3.77it/s]
# 529it [01:32,  5.71it/s]
# train_loss: 0.5241
# val_loss: 0.7016
#
# Train epoch 2:
# 1074it [04:50,  3.69it/s]
# 529it [01:26,  6.13it/s]
# train_loss: 1.0346
# val_loss: 3.0077
#
# Train epoch 3:
# 1074it [04:51,  3.69it/s]
# 529it [01:25,  6.15it/s]
# train_loss: 9.9595
# val_loss: 13.1901
#
# Train epoch 4:
# 1074it [04:51,  3.68it/s]
# 529it [01:25,  6.16it/s]
# train_loss: 21.4865
# val_loss: 39.0191
#
# Train epoch 5:
# 1074it [04:57,  3.61it/s]
# 529it [01:31,  5.76it/s]
# train_loss: 131.6568
# val_loss: 261.1860
#
# Train epoch 6:
# 1074it [05:08,  3.48it/s]
# 529it [01:32,  5.71it/s]
# train_loss: 658.8449
# val_loss: 1226.2241
#
# Train epoch 7:
# 1074it [05:10,  3.46it/s]
# 529it [01:32,  5.73it/s]
# train_loss: 1712.6547
# val_loss: 2022.8167
#
# Train epoch 8:
# 1074it [05:09,  3.47it/s]
# 529it [01:32,  5.74it/s]
# train_loss: 2261.8259
# val_loss: 2313.0677
#
# Train epoch 9:
# 1074it [05:09,  3.47it/s]
# 529it [01:31,  5.76it/s]
# train_loss: 2600.4046
# val_loss: 2739.2761
#
# Train epoch 10:
# 1074it [05:10,  3.46it/s]
# 529it [01:31,  5.76it/s]
# train_loss: 2832.7434
# val_loss: 2964.8557
#
# Train epoch 11:
# 1074it [05:09,  3.47it/s]
# 529it [01:31,  5.76it/s]
# train_loss: 2841.2941
# val_loss: 2561.3746
#
# No. 3 experiment results:
# Train loss: 0.6012, Val loss: 0.6915, Test loss: 0.7444, RMSE: 2.73, MAE: 0.89, CSI: 0.8242, POD: 0.8576, FAR: 0.0451
#
# No. 4 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [05:09,  3.47it/s]
# 529it [01:31,  5.76it/s]
# train_loss: 0.5936
# val_loss: 0.6932
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/04/model.pth
# Train loss: 0.5936, Val loss: 0.6932, Test loss: 0.7473, RMSE: 2.72, MAE: 0.89, CSI: 0.8226, POD: 0.8578, FAR: 0.0475
#
# Train epoch 1:
# 1074it [05:21,  3.34it/s]
# 529it [01:33,  5.67it/s]
# train_loss: 0.4934
# val_loss: 0.6982
#
# Train epoch 2:
# 1074it [04:51,  3.68it/s]
# 529it [01:25,  6.16it/s]
# train_loss: 0.6237
# val_loss: 0.8860
#
# Train epoch 3:
# 1074it [04:51,  3.69it/s]
# 529it [01:25,  6.15it/s]
# train_loss: 0.6915
# val_loss: 0.8965
#
# Train epoch 4:
# 1074it [04:55,  3.63it/s]
# 529it [01:27,  6.02it/s]
# train_loss: 0.6686
# val_loss: 0.8470
#
# Train epoch 5:
# 1074it [04:51,  3.69it/s]
# 529it [01:25,  6.17it/s]
# train_loss: 0.6933
# val_loss: 1.0166
#
# Train epoch 6:
# 1074it [04:51,  3.68it/s]
# 529it [01:25,  6.19it/s]
# train_loss: 4.3595
# val_loss: 20.5420
#
# Train epoch 7:
# 1074it [04:51,  3.69it/s]
# 529it [01:26,  6.15it/s]
# train_loss: 128.0968
# val_loss: 292.2782
#
# Train epoch 8:
# 1074it [04:52,  3.67it/s]
# 529it [01:25,  6.17it/s]
# train_loss: 456.0236
# val_loss: 563.2943
#
# Train epoch 9:
# 1074it [04:51,  3.69it/s]
# 529it [01:27,  6.07it/s]
# train_loss: 845.4812
# val_loss: 1166.6897
#
# Train epoch 10:
# 1074it [04:53,  3.66it/s]
# 529it [01:26,  6.14it/s]
# train_loss: 1472.2189
# val_loss: 1762.8904
#
# Train epoch 11:
# 1074it [04:52,  3.67it/s]
# 529it [01:26,  6.15it/s]
# train_loss: 1828.4765
# val_loss: 1675.9747
#
# No. 4 experiment results:
# Train loss: 0.5936, Val loss: 0.6932, Test loss: 0.7473, RMSE: 2.72, MAE: 0.89, CSI: 0.8226, POD: 0.8578, FAR: 0.0475
#
# No. 5 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:50,  3.70it/s]
# 529it [01:25,  6.16it/s]
# train_loss: 0.5979
# val_loss: 0.6719
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/05/model.pth
# Train loss: 0.5979, Val loss: 0.6719, Test loss: 0.7334, RMSE: 2.72, MAE: 0.90, CSI: 0.8179, POD: 0.8608, FAR: 0.0574
#
# Train epoch 1:
# 1074it [04:34,  3.92it/s]
# 529it [01:17,  6.83it/s]
# train_loss: 0.4937
# val_loss: 0.6813
#
# Train epoch 2:
# 1074it [04:30,  3.97it/s]
# 529it [01:17,  6.86it/s]
# train_loss: 0.5481
# val_loss: 1.4033
#
# Train epoch 3:
# 1074it [04:33,  3.93it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 3.6425
# val_loss: 3.5453
#
# Train epoch 4:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 18.4452
# val_loss: 38.9517
#
# Train epoch 5:
# 1074it [04:30,  3.97it/s]
# 529it [01:15,  7.00it/s]
# train_loss: 62.6223
# val_loss: 138.6549
#
# Train epoch 6:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.94it/s]
# train_loss: 395.9484
# val_loss: 685.5758
#
# Train epoch 7:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 875.6271
# val_loss: 1191.3192
#
# Train epoch 8:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.94it/s]
# train_loss: 1629.4561
# val_loss: 2101.0799
#
# Train epoch 9:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.96it/s]
# train_loss: 2228.4897
# val_loss: 2270.9295
#
# Train epoch 10:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 2191.3462
# val_loss: 2189.2401
#
# Train epoch 11:
# 1074it [04:32,  3.94it/s]
# 529it [01:16,  6.95it/s]
# train_loss: 2207.9889
# val_loss: 2096.3779
#
# No. 5 experiment results:
# Train loss: 0.5979, Val loss: 0.6719, Test loss: 0.7334, RMSE: 2.72, MAE: 0.90, CSI: 0.8179, POD: 0.8608, FAR: 0.0574
#
# No. 6 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:32,  3.94it/s]
# 529it [01:16,  6.95it/s]
# train_loss: 0.5922
# val_loss: 0.6823
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/06/model.pth
# Train loss: 0.5922, Val loss: 0.6823, Test loss: 0.7664, RMSE: 2.81, MAE: 0.94, CSI: 0.8115, POD: 0.8657, FAR: 0.0716
#
# Train epoch 1:
# 1074it [04:35,  3.90it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 0.5316
# val_loss: 0.7338
#
# Train epoch 2:
# 1074it [04:32,  3.94it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 0.5909
# val_loss: 0.8257
#
# Train epoch 3:
# 1074it [04:32,  3.94it/s]
# 529it [01:16,  6.95it/s]
# train_loss: 0.5890
# val_loss: 0.7607
#
# Train epoch 4:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.6309
# val_loss: 0.8340
#
# Train epoch 5:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.6909
# val_loss: 0.7428
#
# Train epoch 6:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 0.6683
# val_loss: 0.7195
#
# Train epoch 7:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.6565
# val_loss: 0.7704
#
# Train epoch 8:
# 1074it [04:28,  3.99it/s]
# 529it [01:17,  6.85it/s]
# train_loss: 0.6419
# val_loss: 0.7401
#
# Train epoch 9:
# 1074it [04:32,  3.95it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 0.6398
# val_loss: 0.7541
#
# Train epoch 10:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.6386
# val_loss: 0.7879
#
# Train epoch 11:
# 1074it [04:32,  3.94it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 0.6376
# val_loss: 0.7886
#
# No. 6 experiment results:
# Train loss: 0.5922, Val loss: 0.6823, Test loss: 0.7664, RMSE: 2.81, MAE: 0.94, CSI: 0.8115, POD: 0.8657, FAR: 0.0716
#
# No. 7 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.87it/s]
# train_loss: 0.5979
# val_loss: 0.7101
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/07/model.pth
# Train loss: 0.5979, Val loss: 0.7101, Test loss: 0.7656, RMSE: 2.73, MAE: 0.88, CSI: 0.8237, POD: 0.8540, FAR: 0.0412
#
# Train epoch 1:
# 1074it [04:36,  3.89it/s]
# 529it [01:17,  6.83it/s]
# train_loss: 0.5194
# val_loss: 0.7061
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/07/model.pth
# Train loss: 0.5194, Val loss: 0.7061, Test loss: 0.8125, RMSE: 2.78, MAE: 0.92, CSI: 0.8088, POD: 0.8675, FAR: 0.0772
#
# Train epoch 2:
# 1074it [04:37,  3.87it/s]
# 529it [01:17,  6.81it/s]
# train_loss: 0.5274
# val_loss: 0.6931
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/07/model.pth
# Train loss: 0.5274, Val loss: 0.6931, Test loss: 0.8181, RMSE: 2.75, MAE: 0.90, CSI: 0.8154, POD: 0.8569, FAR: 0.0560
#
# Train epoch 3:
# 1074it [04:32,  3.95it/s]
# 529it [01:15,  6.97it/s]
# train_loss: 0.5576
# val_loss: 0.6836
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/07/model.pth
# Train loss: 0.5576, Val loss: 0.6836, Test loss: 0.7871, RMSE: 2.79, MAE: 0.93, CSI: 0.8129, POD: 0.8576, FAR: 0.0602
#
# Train epoch 4:
# 1074it [04:27,  4.01it/s]
# 529it [01:16,  6.94it/s]
# train_loss: 0.6674
# val_loss: 0.8723
#
# Train epoch 5:
# 1074it [04:31,  3.95it/s]
# 529it [01:17,  6.85it/s]
# train_loss: 0.7017
# val_loss: 0.8209
#
# Train epoch 6:
# 1074it [04:32,  3.94it/s]
# 529it [01:17,  6.79it/s]
# train_loss: 0.6888
# val_loss: 0.8219
#
# Train epoch 7:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 0.6666
# val_loss: 0.8127
#
# Train epoch 8:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 1.2804
# val_loss: 1.3630
#
# Train epoch 9:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 1.5957
# val_loss: 3.3878
#
# Train epoch 10:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 13.3810
# val_loss: 7.9513
#
# Train epoch 11:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 5.5355
# val_loss: 9.2263
#
# Train epoch 12:
# 1074it [04:33,  3.93it/s]
# 529it [01:16,  6.95it/s]
# train_loss: 19.9272
# val_loss: 42.4760
#
# Train epoch 13:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 83.5915
# val_loss: 129.1089
#
# Train epoch 14:
# 1074it [04:32,  3.94it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 165.9612
# val_loss: 200.3560
#
# No. 7 experiment results:
# Train loss: 0.5576, Val loss: 0.6836, Test loss: 0.7871, RMSE: 2.79, MAE: 0.93, CSI: 0.8129, POD: 0.8576, FAR: 0.0602
#
# No. 8 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 0.5797
# val_loss: 0.7010
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/08/model.pth
# Train loss: 0.5797, Val loss: 0.7010, Test loss: 0.7432, RMSE: 2.76, MAE: 0.92, CSI: 0.8153, POD: 0.8590, FAR: 0.0588
#
# Train epoch 1:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 0.5053
# val_loss: 0.7336
#
# Train epoch 2:
# 1074it [04:32,  3.95it/s]
# 529it [01:16,  6.94it/s]
# train_loss: 0.5751
# val_loss: 0.8082
#
# Train epoch 3:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.95it/s]
# train_loss: 0.7166
# val_loss: 3.5232
#
# Train epoch 4:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.95it/s]
# train_loss: 7.8543
# val_loss: 4.6603
#
# Train epoch 5:
# 1074it [04:30,  3.97it/s]
# 529it [01:15,  7.00it/s]
# train_loss: 33.4858
# val_loss: 86.5157
#
# Train epoch 6:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 182.8261
# val_loss: 310.0914
#
# Train epoch 7:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 421.8029
# val_loss: 627.8797
#
# Train epoch 8:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 724.1288
# val_loss: 701.2952
#
# Train epoch 9:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 624.4648
# val_loss: 712.2605
#
# Train epoch 10:
# 1074it [04:31,  3.96it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 580.5786
# val_loss: 795.8902
#
# Train epoch 11:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 973.5134
# val_loss: 1153.2228
#
# No. 8 experiment results:
# Train loss: 0.5797, Val loss: 0.7010, Test loss: 0.7432, RMSE: 2.76, MAE: 0.92, CSI: 0.8153, POD: 0.8590, FAR: 0.0588
#
# No. 9 experiment ~~~
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Train epoch 0:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.6027
# val_loss: 0.6955
# Minimum val loss!!!
# Save model: /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/09/model.pth
# Train loss: 0.6027, Val loss: 0.6955, Test loss: 0.7316, RMSE: 2.74, MAE: 0.91, CSI: 0.8215, POD: 0.8555, FAR: 0.0461
#
# Train epoch 1:
# 1074it [04:33,  3.93it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 0.5004
# val_loss: 0.7665
#
# Train epoch 2:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 0.5938
# val_loss: 0.9531
#
# Train epoch 3:
# 1074it [04:29,  3.98it/s]
# 529it [01:16,  6.93it/s]
# train_loss: 1.5509
# val_loss: 1.8714
#
# Train epoch 4:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.88it/s]
# train_loss: 19.2726
# val_loss: 49.7798
#
# Train epoch 5:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.90it/s]
# train_loss: 184.0623
# val_loss: 318.5803
#
# Train epoch 6:
# 1074it [04:32,  3.95it/s]
# 529it [01:16,  6.88it/s]
# train_loss: 500.3033
# val_loss: 617.3684
#
# Train epoch 7:
# 1074it [04:30,  3.97it/s]
# 529it [01:16,  6.89it/s]
# train_loss: 769.8185
# val_loss: 890.0751
#
# Train epoch 8:
# 1074it [04:33,  3.93it/s]
# 529it [01:17,  6.85it/s]
# train_loss: 954.1080
# val_loss: 1096.6881
#
# Train epoch 9:
# 1074it [04:31,  3.95it/s]
# 529it [01:16,  6.91it/s]
# train_loss: 1317.4180
# val_loss: 1501.9346
#
# Train epoch 10:
# 1074it [04:30,  3.97it/s]
# 529it [01:17,  6.84it/s]
# train_loss: 1543.5587
# val_loss: 1612.3258
#
# Train epoch 11:
# 1074it [04:32,  3.95it/s]
# 529it [01:16,  6.92it/s]
# train_loss: 1762.8512
# val_loss: 1704.6266
#
# No. 9 experiment results:
# Train loss: 0.6027, Val loss: 0.6955, Test loss: 0.7316, RMSE: 2.74, MAE: 0.91, CSI: 0.8215, POD: 0.8555, FAR: 0.0461
# =========================
#
# ============== Train Info ==============
# Dataset number: 1
# Model: PM25_GNN
# Train: 2017-01-02T00:00:00+00:00 --> 2018-12-31T00:00:00+00:00
# Val: 2020-01-01T00:00:00+00:00 --> 2020-12-31T00:00:00+00:00
# Test: 2021-01-01T00:00:00+00:00 --> 2021-12-31T00:00:00+00:00
# City number: 112
# Use metero: ['100m_u_component_of_wind', '100m_v_component_of_wind', '2m_dewpoint_temperature', '2m_temperature', 'boundary_layer_height', 'total_precipitation', 'surface_pressure', 'u_component_of_wind+950', 'v_component_of_wind+950', 'frp_25km_idw', 'frp_50km_idw', 'frp_100km_idw', 'frp_500km_idw', 'numfires', 'julian_date', 'time_of_day']
# batch_size: 16
# epochs: 50
# hist_len: 240
# pred_len: 48
# weight_decay: 0.0005
# early_stop: 10
# lr: 0.0005
# ========================================
#
# ---------------------------------------
# train_loss | mean: 0.5862 std: 0.0189
# val_loss   | mean: 0.6860 std: 0.0125
# test_loss  | mean: 0.7449 std: 0.0175
# RMSE       | mean: 2.7495 std: 0.0306
# MAE        | mean: 0.9103 std: 0.0152
# CSI        | mean: 0.8185 std: 0.0041
# POD        | mean: 0.8593 std: 0.0034
# FAR        | mean: 0.0547 std: 0.0087
#
# PM25_GNN(
#   (fc_in): Linear(in_features=21, out_features=64, bias=True)
#   (graph_gnn): GraphGNN(
#     (edge_mlp): Sequential(
#       (0): Linear(in_features=45, out_features=32, bias=True)
#       (1): Sigmoid()
#       (2): Linear(in_features=32, out_features=30, bias=True)
#       (3): Sigmoid()
#     )
#     (node_mlp): Sequential(
#       (0): Linear(in_features=30, out_features=13, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (gru_cell): GRUCell(
#     (x2h): Linear(in_features=34, out_features=192, bias=True)
#     (h2h): Linear(in_features=64, out_features=192, bias=True)
#   )
#   (fc_out): Linear(in_features=64, out_features=1, bias=True)
# )
# /content/drive/MyDrive/ds-capstone/pm25_forecasting_gnn/data/pm25gnn/results/240_48/1/PM25_GNN/20250418020336/metric.txt
